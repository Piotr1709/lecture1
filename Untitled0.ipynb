# %% [markdown]
# <a href="https://colab.research.google.com/github/Piotr1709/lecture1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy
import pandas as pd
data = pd.read_csv("Salary Data (2).csv")
data.head()
plt.scatter(data["Age"],data["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
